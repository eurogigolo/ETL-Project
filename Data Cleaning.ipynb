# %%
import pandas as pd
from sqlalchemy import create_engine
import re

# %%
astro_file = "./ETL-Project-Data/astronauts.csv"
astro_data_df = pd.read_csv(astro_file)
astro_data_df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 0                Geology           NaN                     NaN              2
# 1          Solar Physics           NaN                     NaN              1
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
# 4           Astronautics       Colonel  US Air Force (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
#
#                                             Missions Death Date Death Mission
# 0             STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# 1                              STS 51-F (Challenger)        NaN           NaN
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN

# %%
space_file = "./ETL-Project-Data/Space_Corrected.csv"
space_data_df = pd.read_csv(space_file)
space_data_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Company Name  \
# 0           0             0       SpaceX
# 1           1             1         CASC
# 2           2             2       SpaceX
# 3           3             3    Roscosmos
# 4           4             4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                         Datum                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Status Rocket  Rocket Status Mission
# 0  StatusActive   50.0         Success
# 1  StatusActive  29.75         Success
# 2  StatusActive     NaN        Success
# 3  StatusActive   65.0         Success
# 4  StatusActive  145.0         Success

# %%
new_astro_df = astro_data_df[["Name", "Birth Date", "Missions", "Space Flight (hr)", "Space Walks (hr)"]].copy()

new_astro_df['Missions'] = new_astro_df['Missions'].str.replace(r"\(.*\)","")

new_astro_df = pd.concat([new_astro_df, new_astro_df["Missions"].str.split(', ', expand=True)], axis=1)
new_astro_df.head()
# Out:
#                Name Birth Date              Missions  Space Flight (hr)  \
# 0   Joseph M. Acaba  5/17/1967              STS-119                3307
# 1    Loren W. Acton   3/7/1936             STS 51-F                 190
# 2  James C. Adamson   3/3/1946               STS-28                 334
# 3   Thomas D. Akers  5/20/1951               STS-41                 814
# 4       Buzz Aldrin  1/20/1930  Gemini 12, Apollo 11                289
#
#    Space Walks (hr)          0          1     2     3     4
# 0              13.0   STS-119        None  None  None  None
# 1               0.0  STS 51-F        None  None  None  None
# 2               0.0    STS-28        None  None  None  None
# 3              29.0    STS-41        None  None  None  None
# 4               8.0  Gemini 12  Apollo 11  None  None  None

# %%
new_space_df = space_data_df[["Company Name", "Location", "Datum", "Detail", " Rocket", "Status Mission"]].copy()

new_space_df.tail()
# Out:
#      Company Name                                   Location  \
# 4319      US Navy   LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA   LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy   LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum                      Detail  Rocket  \
# 4319  Wed Feb 05, 1958 07:33 UTC   Vanguard | Vanguard TV3BU     NaN
# 4320  Sat Feb 01, 1958 03:48 UTC         Juno I | Explorer 1     NaN
# 4321  Fri Dec 06, 1957 16:44 UTC     Vanguard | Vanguard TV3     NaN
# 4322  Sun Nov 03, 1957 02:30 UTC  Sputnik 8K71PS | Sputnik-2     NaN
# 4323  Fri Oct 04, 1957 19:28 UTC  Sputnik 8K71PS | Sputnik-1     NaN
#
#      Status Mission
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
